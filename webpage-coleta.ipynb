# %%
import re
import urllib.request
from bs4 import BeautifulSoup
     
html = urllib.request.urlopen('https://www.uol.com.br/')
soup = BeautifulSoup(html)
data = soup.findAll(text=True)

     
def visible(element):
    if element.parent.name in ['style', 'script', '[document]', 'head', 'title', '\n', '\t']:
        return False
    elif re.match('<!--.*-->', str(element.encode('utf-8'))):
        return False
    return True
     
result = filter(visible, data)

#result  = [r for i in result i in ['\t','\n']]

for r in result:
    if not r in ['\n','\t', '', ' ']:
        print(r)
# Out:
# /usr/lib/python3/dist-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /usr/lib/python3.5/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))
# MENU
# Assine
# Bate-papo
# Notícias
# Carros
# Economia
# Folha
# Esporte
# Entretenimento
# TV e famosos
# Jogos
# Estilo
# Educação
# Vídeos
# TAB
# Aplicativos
# UOL Host
# PagSeguro
# Cursos
# UOL Resolve
#  Outros canais UOL
# Ainda não tem?
# Crie o seu
# sair
#  Dólar
# R$ 3,115
# topo
# Da Redação
#  UOL acompanha o 3º dia de Rock in Rio
#  Procurador deixa o cargo
#  Em carta de despedida, Janot diz que 'escroques' ainda têm cargos no país
#  Campeonato Brasileiro
#  Mãozinha de Jô devolve favoritismo ao Corinthians
# Com gol polêmico e tropeços dos rivais, paulista abre (mais) vantagem
#  Edmundo: "Quem tem que ver é o árbitro"
#  Euriquinho: "Entrega logo a taça"
#  Flamengo se supera e "dorme" no G-4
#  Veja como ficou a classificação
#  Rock in Rio
#  Público grita 'Fora, Temer' no show de Alicia Keys
# Cantora recebeu líder indígena, que discursou em prol da Amazônia
#  Barney: Whindersson faz show histórico
#  Nile Rodgers fala emocionado de câncer
#  Os melhores da TV americana
#  The Handmaid's Tale e Big Little Lies são as vencedoras do Emmy
#  RiR: música e defesa ambiental
#  Frejat levanta público com defesa da Amazônia e tributo a Cássia Eller
#  Rezende foi contra opinião médica
#  Pacientes que fazem tratamentos alternativos para câncer morrem mais
#  Tensão internacional
#  ONU esgotou opções para lidar com a Coreia do Norte, dizem EUA
#  'Intervenção militar'
#  General do Exército ameaça 'impor solução' para crise política no país
#  Prioridade
#  União quer de volta o dinheiro de corrupção antes da Petrobras
#  Uruguaio tirou bola do brasileiro
#  Neymar e Cavani se desentendem em lances de pênalti e falta no PSG
#  Causando na noite carioca
#  Pabllo Vittar, Fergie e Whindersson Nunes vão a festa pós-Rock in Rio
#  TAB #131 - Influencers de Cristo
#  Youtubers cristãos deixam pastores de lado para conquistar público
#  Jornalista morto aos 65
#  Marcelo Rezende é sepultado sob aplausos em SP
#  Faustão presta homenagem a jornalista
#  Usava bordão até com churrasqueiro
#  É grátis
#  App de notícias do UOL fica mais rápido e com novo visual; baixe
#  Nasce em janeiro
#  Patricia Abravanel é "zoada" por possível nome para filha
#  Negociações
#  Globo se aproxima do PSG por causa da presença de Neymar
# continuar lendo
# Touro
#  Semana começa super bem pra você, num pique de mais concretização e praticidade. Ideias e inspirações vieram de montão, agora é arregaçar as...
# continuar lendo
# Gêmeos
#  Ao invés do pique glamouroso dos últimos dias, esta 2ª feira traz um ritmo mais rápido, nervoso e racional. Pra você, o desafio é ir até o f...
# continuar lendo
# Câncer
#  Tenha cuidado com as palavras, o que inclui e-mails e comunicações em redes sociais em geral. Comentários ásperos podem te ferir, e vice-ver...
# continuar lendo
# Leão
#  Senso de importância pessoal pode ajudar na hora de negociar o valor de um trabalho, mas atrapalha no amor – faça a devida separação entre o...
# continuar lendo
# Virgem
#  A Lua vem para o seu signo, onde encontrará o Sol amanhã; a perspectiva desse encontro astral intensifica emoções, sinalizando um dia de foc...
# continuar lendo
# Libra
#  Você pode se sentir um tanto distraído e com dificuldade de concentração em assuntos corriqueiros. Preocupações talvez fiquem rodando sua me...
# continuar lendo
# Escorpião
#  Mercúrio e Netuno começam a nublar relacionamentos amorosos e sociais. O limite entre eles fica elástico demais – o que pode ser perigoso a ...
# continuar lendo
# Sagitário
#  Fase de encerramento de um ciclo, o dia pede concentração em temas concretos – e que tenham tudo a ver com suas metas e objetivos profission...
# continuar lendo
# Capricórnio
#  Curiosidades e desejos de romper o comum, aprender algo, estudar ou viajar estão em alta nestes dias. Percepção mais apurada e realista de c...
# continuar lendo
# Aquário
#  Abordagens práticas e simplificadoras podem resolver pendências financeiras, o tema destes dias. Você pode ter boas notícias de gente que de...
# continuar lendo
# Peixes
#  De hoje até o fim da semana fique atento ao seu comportamento e às mensagens que passa aos clientes, ao cônjuge ou namorado. Tem algo vago d...
# continuar lendo
# Páginas dos signos
# Áries
# Touro
# Gêmeos
# Câncer
# Leão
# Virgem
# Libra
# Escorpião
# Sagitário
# Capricórnio
# Aquário
# Peixes
# mais lidas
# 1
#  Apresentador de afiliada da Globo é vítima de bala perdida
#  Jornalista havia deixado emissora e seguia para casa quando ficou no fogo cruzado entre polícia e bandidos
# 2
#  Confira como está a classificação do Brasileirão após os jogos de sábado
# 3
#  Namorada de Marcelo Rezende compartilha último momento
# 4
#  Velório de Marcelo Rezende tem brinde e emoção dos fãs
# 5
#  Corinthians vence o Vasco com gol de mão e aumenta vantagem
# host
# www.
# buscar domínio
# E-COMMERCE
#  Como escolher o nome ideal para a sua loja
# E-BOOK
#  Baixe grátis e aprenda a montar sua primeira loja virtual
# segurança digital
# SEGURANÇA ONLINE
#  5 truques para manter sua segurança e privacidade no WhatsApp
# E-BOOK
#  Baixe grátis o e-book e proteja seu celular das ameaças virtuais
# Comunicar erro
# © UOL 1996-2017
#  Ver em:
# Celular
#  -
# Web
